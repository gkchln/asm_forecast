# %% [markdown]
# # Set-up

# %% [markdown]
# ## Imports

# %%
# Standard
import pandas as pd
import numpy as np
pd.options.mode.chained_assignment = None

# Plotting
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()
from tqdm.notebook import tqdm, trange
import plotly.graph_objects as go

# Sci-kit learn imports
from sklearn.ensemble import RandomForestClassifier
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score, average_precision_score, f1_score, classification_report, matthews_corrcoef, PrecisionRecallDisplay
import joblib

# %% [markdown]
# ## Parameters

# %%
scope = 'BID'
input_path = f'../data/3_output/ML_dataset_{scope}.pkl'

start_month = 201901
end_month = 202212

subsample_size = None

target = 'Result'

features_to_encode = [
    'MargTech',
    'WorkDay',
    'Prov',
    'Tech',
]

other_features = [
    'hour',
    'SC_PC1',
    'SC_PC2',
    'IN_PC1',
    'IN_PC2',
    'CT_PC1',
    'CT_PC2',
    'PurchMGP',
    'SellMGP',
    'SolarAngle',
    'DeclAngle',
    'PVold',
    'PVnew',
    'PriceDiff',
]

features = other_features + features_to_encode

# %%
input_df = pd.read_pickle(input_path)
input_df
# Out:
#                              hour      date  year           unit scope  \
# 2018010118UP_ALTOADDA_1_BID    18  20180101  2018  UP_ALTOADDA_1   BID
# 2018010119UP_ALTOADDA_1_BID    19  20180101  2018  UP_ALTOADDA_1   BID
# 2018010120UP_ALTOADDA_1_BID    20  20180101  2018  UP_ALTOADDA_1   BID
# 2018010117UP_ARSIE_1_BID       17  20180101  2018     UP_ARSIE_1   BID
# 2018010118UP_ARSIE_1_BID       18  20180101  2018     UP_ARSIE_1   BID
# ...                           ...       ...   ...            ...   ...
# 2022123117UP_VOGHERA_1_BID     17  20221231  2022   UP_VOGHERA_1   BID
# 2022123118UP_VOGHERA_1_BID     18  20221231  2022   UP_VOGHERA_1   BID
# 2022123119UP_VOGHERA_1_BID     19  20221231  2022   UP_VOGHERA_1   BID
# 2022123120UP_VOGHERA_1_BID     20  20221231  2022   UP_VOGHERA_1   BID
# 2022123121UP_VOGHERA_1_BID     21  20221231  2022   UP_VOGHERA_1   BID
#
#                                SC_PC1    SC_PC2    IN_PC1    IN_PC2    CT_PC1  \
# 2018010118UP_ALTOADDA_1_BID  2.083112  0.480035 -1.932233 -0.782315  1.912031
# 2018010119UP_ALTOADDA_1_BID  1.249924  0.598779 -1.772487 -0.866850  0.891173
# 2018010120UP_ALTOADDA_1_BID  0.243493  0.768175 -1.758348 -0.872364 -0.334594
# 2018010117UP_ARSIE_1_BID     3.456008  0.661794 -2.372137 -0.624680  3.037220
# 2018010118UP_ARSIE_1_BID     2.083112  0.480035 -1.932233 -0.782315  1.912031
# ...                               ...       ...       ...       ...       ...
# 2022123117UP_VOGHERA_1_BID   0.237656 -2.008471 -1.806319  0.875068 -2.527147
# 2022123118UP_VOGHERA_1_BID   0.055686 -2.259989 -1.329127  0.607693 -2.561474
# 2022123119UP_VOGHERA_1_BID  -0.051126 -2.357014 -1.293692  0.548271 -2.484197
# 2022123120UP_VOGHERA_1_BID  -0.029177 -2.330178 -1.385200  0.630366 -2.484197
# 2022123121UP_VOGHERA_1_BID  -0.075154 -0.954465 -1.872673  0.745683 -2.449869
#
#                              ...  SolarAngle  DeclAngle  WorkDay     Prov  \
# 2018010118UP_ALTOADDA_1_BID  ...   76.773894 -23.011637  holiday   Milano
# 2018010119UP_ALTOADDA_1_BID  ...   91.773894 -23.011637  holiday   Milano
# 2018010120UP_ALTOADDA_1_BID  ...  106.773894 -23.011637  holiday   Milano
# 2018010117UP_ARSIE_1_BID     ...   61.773894 -23.011637  holiday  Belluno
# 2018010118UP_ARSIE_1_BID     ...   76.773894 -23.011637  holiday  Belluno
# ...                          ...         ...        ...      ...      ...
# 2022123117UP_VOGHERA_1_BID   ...   61.887169 -23.085911  holiday    Pavia
# 2022123118UP_VOGHERA_1_BID   ...   76.887169 -23.085911  holiday    Pavia
# 2022123119UP_VOGHERA_1_BID   ...   91.887169 -23.085911  holiday    Pavia
# 2022123120UP_VOGHERA_1_BID   ...  106.887169 -23.085911  holiday    Pavia
# 2022123121UP_VOGHERA_1_BID   ...  121.887169 -23.085911  holiday    Pavia
#
#                                                         Tech  PVold  PVnew  \
# 2018010118UP_ALTOADDA_1_BID  Hydro Run-of-river and poundage  0.095  0.095
# 2018010119UP_ALTOADDA_1_BID  Hydro Run-of-river and poundage  0.095  0.095
# 2018010120UP_ALTOADDA_1_BID  Hydro Run-of-river and poundage  0.095  0.095
# 2018010117UP_ARSIE_1_BID     Hydro Run-of-river and poundage  0.627  0.627
# 2018010118UP_ARSIE_1_BID     Hydro Run-of-river and poundage  1.000  1.000
# ...                                                      ...    ...    ...
# 2022123117UP_VOGHERA_1_BID                        Fossil Gas  0.540  0.540
# 2022123118UP_VOGHERA_1_BID                        Fossil Gas  1.000  1.000
# 2022123119UP_VOGHERA_1_BID                        Fossil Gas  1.000  1.000
# 2022123120UP_VOGHERA_1_BID                        Fossil Gas  1.000  1.000
# 2022123121UP_VOGHERA_1_BID                        Fossil Gas  0.573  0.573
#
#                               Price PriceDiff Result
# 2018010118UP_ALTOADDA_1_BID   26.22    -0.349  False
# 2018010119UP_ALTOADDA_1_BID   26.22    -0.329  False
# 2018010120UP_ALTOADDA_1_BID   26.22    -0.324  False
# 2018010117UP_ARSIE_1_BID       0.00    -1.000  False
# 2018010118UP_ARSIE_1_BID       0.00    -1.000  False
# ...                             ...       ...    ...
# 2022123117UP_VOGHERA_1_BID   135.00    -0.350  False
# 2022123118UP_VOGHERA_1_BID   136.00    -0.420   True
# 2022123119UP_VOGHERA_1_BID   138.00    -0.414   True
# 2022123120UP_VOGHERA_1_BID   141.00    -0.405   True
# 2022123121UP_VOGHERA_1_BID   143.00    -0.369  False
#
# [2177292 rows x 26 columns]

# %%
# We take of the fact that some categories could be absent in the training set but present in the test set
categories = [input_df[feature].unique() for feature in features_to_encode]

feature_transformer = make_column_transformer(
    (OneHotEncoder(categories=categories), features_to_encode),
    remainder="passthrough"
)

# %% [markdown]
# ## Functions

# %%
def get_X_y(df):
    X = feature_transformer.fit_transform(df[features])
    y = df[target]
    return X, y

# %%
def predict_proba_monthly_recal(model, df):
    """
    For each observation of the dataset, if M is the corresponding month, outputs the predicted probability of the model when trained on the M-12 to M-1 period.
    We hence fit a number of models equal to the number of months in the dataset.
    This allows to test the the performance of the model in a "live" setting, where each month, the model is recalibrated with the new data.
    """
    X, y = get_X_y(df)
    
    observation_month = df.index.str[:6].astype(int)
    months = sorted(observation_month.unique())
    test_months = [month for month in  months if month >= start_month and month <= end_month]
    y_probs_list =  []

    for test_month in tqdm(test_months):
        # For every month M, we take the training period as M-12 to M-1
        idx = months.index(test_month)
        train_months = months[idx-12:idx]
        X_train, y_train = get_X_y(df[observation_month.isin(train_months)])
        # And the test period as month M
        X_test, y_test = get_X_y(df[observation_month == test_month])

        model.fit(X_train, y_train)

        y_probs = model.predict_proba(X_test)[:,1]

        APS = average_precision_score(y_test, y_probs)
        print('Average Precision Score over {:,} samples for month {} is: {}'.format(len(y_test), test_month, round(APS, 3)))
        print("\n")

        y_probs_list.append(y_probs)
    
    return pd.Series(np.concatenate(y_probs_list, axis=0), index=df[observation_month.isin(test_months)].index)

# %% [markdown]
# # Main

# %% [markdown]
# ## Preprocessing

# %%
# Subsample
if subsample_size is not None:
    print(f'Subsampled {subsample_size} rows from the input dataset')
    df = input_df.copy()
    df['order'] = range(len(df))
    df = df.sample(subsample_size).sort_values('order')
    df.drop('order', axis=1, inplace=True)
else:
    df = input_df.copy()

# %% [markdown]
# ## Model

# %% [markdown]
# # Run test with monthly recal

# %%
# %%time

clf = RandomForestClassifier(
    random_state=42,
    n_jobs=-1
)

y_probs = predict_proba_monthly_recal(clf, df)
# Out:
#   0%|          | 0/48 [00:00<?, ?it/s]
# Average Precision Score over 46,525 samples for month 201901 is: 0.664
#
#
# Average Precision Score over 38,675 samples for month 201902 is: 0.695
#
#
# Average Precision Score over 39,137 samples for month 201903 is: 0.763
#
#
# Average Precision Score over 42,489 samples for month 201904 is: 0.73
#
#
# Average Precision Score over 46,778 samples for month 201905 is: 0.742
#
#
# Average Precision Score over 48,778 samples for month 201906 is: 0.585
#
#
# Average Precision Score over 54,320 samples for month 201907 is: 0.589
#
#
# Average Precision Score over 40,523 samples for month 201908 is: 0.633
#
#
# Average Precision Score over 37,283 samples for month 201909 is: 0.642
#
#
# Average Precision Score over 34,730 samples for month 201910 is: 0.725
#
#
# Average Precision Score over 35,962 samples for month 201911 is: 0.812
#
#
# Average Precision Score over 36,277 samples for month 201912 is: 0.868
#
#
# Average Precision Score over 40,846 samples for month 202001 is: 0.797
#
#
# Average Precision Score over 33,777 samples for month 202002 is: 0.819
#
#
# Average Precision Score over 28,087 samples for month 202003 is: 0.859
#
#
# Average Precision Score over 29,173 samples for month 202004 is: 0.854
#
#
# Average Precision Score over 30,523 samples for month 202005 is: 0.886
#
#
# Average Precision Score over 37,372 samples for month 202006 is: 0.766
#
#
# Average Precision Score over 43,157 samples for month 202007 is: 0.669
#
#
# Average Precision Score over 37,697 samples for month 202008 is: 0.697
#
#
# Average Precision Score over 35,846 samples for month 202009 is: 0.687
#
#
# Average Precision Score over 30,707 samples for month 202010 is: 0.878
#
#
# Average Precision Score over 35,487 samples for month 202011 is: 0.815
#
#
# Average Precision Score over 35,303 samples for month 202012 is: 0.829
#
#
# Average Precision Score over 36,118 samples for month 202101 is: 0.802
#
#
# Average Precision Score over 30,635 samples for month 202102 is: 0.859
#
#
# Average Precision Score over 34,285 samples for month 202103 is: 0.809
#
#
# Average Precision Score over 32,706 samples for month 202104 is: 0.779
#
#
# Average Precision Score over 29,759 samples for month 202105 is: 0.886
#
#
# Average Precision Score over 33,056 samples for month 202106 is: 0.773
#
#
# Average Precision Score over 37,899 samples for month 202107 is: 0.71
#
#
# Average Precision Score over 29,797 samples for month 202108 is: 0.781
#
#
# Average Precision Score over 30,259 samples for month 202109 is: 0.674
#
#
# Average Precision Score over 28,276 samples for month 202110 is: 0.643
#
#
# Average Precision Score over 36,325 samples for month 202111 is: 0.461
#
#
# Average Precision Score over 35,042 samples for month 202112 is: 0.557
#
#
# Average Precision Score over 34,706 samples for month 202201 is: 0.634
#
#
# Average Precision Score over 28,270 samples for month 202202 is: 0.558
#
#
# Average Precision Score over 26,998 samples for month 202203 is: 0.569
#
#
# Average Precision Score over 24,077 samples for month 202204 is: 0.649
#
#
# Average Precision Score over 27,640 samples for month 202205 is: 0.674
#
#
# Average Precision Score over 29,643 samples for month 202206 is: 0.674
#
#
# Average Precision Score over 32,136 samples for month 202207 is: 0.619
#
#
# Average Precision Score over 27,629 samples for month 202208 is: 0.67
#
#
# Average Precision Score over 25,016 samples for month 202209 is: 0.677
#
#
# Average Precision Score over 23,828 samples for month 202210 is: 0.706
#
#
# Average Precision Score over 25,228 samples for month 202211 is: 0.672
#
#
# Average Precision Score over 27,919 samples for month 202212 is: 0.686
#
#
# CPU times: user 21h 14min 43s, sys: 3min 46s, total: 21h 18min 29s
# Wall time: 2h 6min 24s

# %%
y_probs
# Out:
# 2019010110UP_ALTOADDA_1_BID    0.010
# 2019010111UP_ALTOADDA_1_BID    0.010
# 2019010113UP_ALTOADDA_1_BID    0.010
# 2019010114UP_ALTOADDA_1_BID    0.020
# 2019010116UP_ALTOADDA_1_BID    0.020
#                                ...
# 2022123117UP_VOGHERA_1_BID     0.110
# 2022123118UP_VOGHERA_1_BID     0.533
# 2022123119UP_VOGHERA_1_BID     0.487
# 2022123120UP_VOGHERA_1_BID     0.452
# 2022123121UP_VOGHERA_1_BID     0.130
# Length: 1646699, dtype: float64

# %%
y_probs.to_pickle(f'{scope}/model_predictions/predicted_probs_monthly_recal_rolling_12m.pkl')

# %% [markdown]
# ---

# %% [markdown]
# # TESTS
