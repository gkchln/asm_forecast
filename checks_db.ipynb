# %%
import pandas as pd

# %%
db_up = pd.read_pickle("DBup_2019.pickle")
db_dw = pd.read_pickle("../downward/DBdw_2019.pickle")

# %%
db_up
# Out:
#                              hour    SC_PC1    SC_PC2    IN_PC1    IN_PC2  \
# idx
# 01/01/20191UP_ACTV_1            1  3.353367  0.050663  -3.76401  0.464396
# 01/01/20191UP_ALTOADDA_1        1  3.353367  0.050663  -3.76401  0.464396
# 01/01/20191UP_ARSIE_1           1  3.353367  0.050663  -3.76401  0.464396
# 01/01/20191UP_AZOTATI_5         1  3.353367  0.050663  -3.76401  0.464396
# 01/01/20191UP_BARGI_CEN_1       1  3.353367  0.050663  -3.76401  0.464396
# ...                           ...       ...       ...       ...       ...
# 31/12/201924UP_VALCAMONICA_1   24  0.099112  0.710441 -3.129271  0.576563
# 31/12/201924UP_VALPELLIN_1     24  0.099112  0.710441 -3.129271  0.576563
# 31/12/201924UP_VAL_NOANA_1     24  0.099112  0.710441 -3.129271  0.576563
# 31/12/201924UP_VENAUS_1        24  0.099112  0.710441 -3.129271  0.576563
# 31/12/201924UP_VILLA_1         24  0.099112  0.710441 -3.129271  0.576563
#
#                                 CT_PC1    CT_PC2   PurchMGP    SellMGP  \
# ...
